# %%
from bs4 import BeautifulSoup
# conda install requests
import requests #requests imformation from a particular library

# %%
#getting html text of the website
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
# print (html_text)

soup = BeautifulSoup(html_text, 'lxml') #lxml - parsing
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

for job in jobs:
    published_date = job.find('span', class_ = 'sim-posted').span.text
    # if the word 'few' is in the published date, do not include it
    if 'few' not in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ', '')
        skills = job.find('span', class_ = 'srp-skills').text.replace(' ', '')
        

        print (f'''
        Company name: {company_name}
        Required  Skills: {skills}
        Published  Date: {published_date}
        ''')
# Out:
#         Company name:
# CONNECTING2WORK
#
#
#         Required  Skills:
# python,storage,django,testingtools,debugging
#
#
#         Published  Date: Posted 2 days ago
#
#
#         Company name:
# glanmanagementconsultancypvt.ltd.
#
#
#         Required  Skills:
# python,rdbms,mysql,cloudcomputing,docker,sql
#
#
#         Published  Date: Posted 3 days ago
#
#
#         Company name:
# CONNECTING2WORK
#
#
#         Required  Skills:
#
# securitycompliance,python,html5,mobile,javascript,database,django,debugging
#
#
#         Published  Date: Posted 2 days ago
#
#
#         Company name:
# CONNECTING2WORK
#
#
#         Required  Skills:
# python,css,github,hosting,bugfixing,bootstrap,javascript,jquery,django,heroku,json,html,api
#
#
#         Published  Date: Posted 2 days ago
#
#
#         Company name:
# CONNECTING2WORK
#
#
#         Required  Skills:
# python,css,github,hosting,bugfixing,bootstrap,javascript,jquery,django,heroku,json,html,api
#
#
# ...

# %%
with open ('test_site.html', 'r') as html_file:
    content = html_file.read() #all the html code of the website
    
    soup = BeautifulSoup(content, 'lxml')
    # print(soup.prettify()) ##will print the html in a more 'pretty' way
    
    #grab html tags
    tags = soup.find('h5') #only finds the first 'h5' tag
    tags = soup.find_all('h2') #makes a list of all 'h5' tags
    
    # tags = soup.find_all('div', class_ = 'site-heading')
    
    for tag in tags:
        print (tag.text) #prints just the text related to those tags
# Out:
# 						E-commerce site
#
#
#
#
# 						E-commerce site with pagination links
#
#
#
#
# 						E-commerce site with AJAX pagination links
#
#
#
#
# 						E-commerce site with "Load more" buttons
#
#
#
#
# 						E-commerce site that loads items while scrolling
#
#
#
# Table playground
