# %% [markdown]
# # An Analysis of the Berlin Marathon Runners
# - How have the average times changed over the years?
# - How have the fastest times changed over the years?
# - How does age and gender affect running times
#     - Finisher times over the years
# - Where are most runners from?
# - Where are the fastest runners from?

# %% [markdown]
# This project takes the Berlin Marathon dataset and analyzes it look at how running times have changed over the years, and over different age groups and genders. It also takes a look into where the top runners are from.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import panel as pn
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a7acb66f-0d67-4d76-9b5c-166806345c31'>
#   <div id="b6f6899d-0689-4837-a886-89689bd7a615" data-root-id="a7acb66f-0d67-4d76-9b5c-166806345c31" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0dc06621-01c2-491f-acc8-58955cd8272d":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a7acb66f-0d67-4d76-9b5c-166806345c31"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6d8d95c7-1a1e-46fb-aa59-462f3e782694","attributes":{"plot_id":"a7acb66f-0d67-4d76-9b5c-166806345c31","comm_id":"b43d88a931544d3eb949c4d6c598c007","client_comm_id":"1242099eb8ab431bb68b4c415cdc16ca"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"0dc06621-01c2-491f-acc8-58955cd8272d","roots":{"a7acb66f-0d67-4d76-9b5c-166806345c31":"b6f6899d-0689-4837-a886-89689bd7a615"},"root_ids":["a7acb66f-0d67-4d76-9b5c-166806345c31"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#format: year, country, gender, age, time
#(all participants)
berlin_marathon = pd.read_csv('1_running_datasets/berlin_marathon_1974_2023.csv')

age_null_values = ['H', 'JU20', 'L1', 'L2', 'L', 'L3', 'D1', 'L4', 'D3', 'D2',
                  'BM','A', 'B', 'C', 'DH', 'DA', 'DB', 'DJ', 'M0', 'Ber', 'M',
                  'M<', 'Jug']

#data cleaning
berlin_marathon = berlin_marathon[~(berlin_marathon['time'].isin(['–', 'DSQ', 'no time']))&
                                  ~(berlin_marathon['age'].isin(age_null_values))]
#convert time to hrs
berlin_marathon['time_hrs'] = pd.to_timedelta(berlin_marathon['time']).dt.total_seconds() / 3600
berlin_marathon.dropna(subset = 'time_hrs', how='any')
berlin_marathon['age'] = pd.to_numeric(berlin_marathon['age'])
# Out:
# /var/folders/_p/y56kr6vs1fz7ycsbxhyqwwwc0000gn/T/ipykernel_90662/829007302.py:3: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   berlin_marathon = pd.read_csv('1_running_datasets/berlin_marathon_1974_2023.csv')

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start=1974, end=2023, step=1, value=2023)
idf = berlin_marathon.interactive()

# %% [markdown]
# ## Average and Finishing times
# - How have average times changed over the years?
#     - Overall average time has increased. Likely due to the increase in interest in the sport.
# - How has the fastest time changed over the years?
#     - Finishing times have decreased. obvs. because records are meant to be broken.

# %%
overall_times = pd.DataFrame(berlin_marathon.groupby('year')['time_hrs'].mean().rename('Average Times'))#.hvplot(kind = 'scatter', title = 'Average times over the years')
overall_times['Finishing times'] = berlin_marathon.groupby('year')['time_hrs'].min()
overall_times_plot = overall_times.hvplot(title = 'Average and Finishing times', xlabel = 'year', ylabel = 'time(hrs)')
overall_times_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %% [markdown]
# ## Table df

# %%
marathon_table = idf.drop(columns = ['time']).pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') 
marathon_table
# Out:
# <div id='d96c9865-bd09-4d30-8a8a-68634af9bf6a'>
#   <div id="fc7f4ccd-baa3-4547-8a4b-aedb414927aa" data-root-id="d96c9865-bd09-4d30-8a8a-68634af9bf6a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"83b42741-80fe-4406-b2be-d609ea50de1c":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d96c9865-bd09-4d30-8a8a-68634af9bf6a","attributes":{"name":"Row01148","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"a1800c51-e59a-4ab8-b13e-3a9db296acf0","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"6daabdff-b1c2-4dff-9fc7-00455ef85b94","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9843e7eb-669d-4e6e-bf58-b84743dd586d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ee89725c-9a2b-4ba7-a357-7b6af019f1fe","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"fa256f83-f997-4873-a90a-8c6eefd49599","attributes":{"name":"Column01139","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"a1800c51-e59a-4ab8-b13e-3a9db296acf0"},{"id":"6daabdff-b1c2-4dff-9fc7-00455ef85b94"},{"id":"9843e7eb-669d-4e6e-bf58-b84743dd586d"},{"id":"ee89725c-9a2b-4ba7-a357-7b6af019f1fe"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"be3841c6-92ca-4415-80eb-37d53590e900","attributes":{"name":"Column01145","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"a1800c51-e59a-4ab8-b13e-3a9db296acf0"},{"id":"6daabdff-b1c2-4dff-9fc7-00455ef85b94"},{"id":"9843e7eb-669d-4e6e-bf58-b84743dd586d"},{"id":"ee89725c-9a2b-4ba7-a357-7b6af019f1fe"}],"margin":0,"align":"start"}},{"type":"object","name":"Row","id":"c2dd6697-66d0-4c8d-8bcc-2aa07f29d8ce","attributes":{"name":"Row01142","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"a1800c51-e59a-4ab8-b13e-3a9db296acf0"},{"id":"6daabdff-b1c2-4dff-9fc7-00455ef85b94"},{"id":"9843e7eb-669d-4e6e-bf58-b84743dd586d"},{"id":"ee89725c-9a2b-4ba7-a357-7b6af019f1fe"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.tabulator.DataTabulator","id":"8d8eb205-c9d9-4687-90bd-0afb02af0f43","attributes":{"subscribed_events":{"type":"set","entries":["table-edit","cell-click"]},"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"a1800c51-e59a-4ab8-b13e-3a9db296acf0"},{"type":"object","name":"ImportedStyleSheet","id":"5437e567-bbdd-41cf-84f1-025c636c8df5","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/font-awesome/css/all.min.css"}},{"id":"9843e7eb-669d-4e6e-bf58-b84743dd586d"},{"id":"ee89725c-9a2b-4ba7-a357-7b6af019f1fe"},{"type":"object","name":"ImportedStyleSheet","id":"44b4bdf0-bf63-4509-9562-cec8b9c40cf6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/datatabulator/tabulator-tables@5.5.0/dist/css/tabulator_simple.min.css"}}],"margin":[5,10],"sizing_mode":"stretch_width","align":"start","configuration":{"type":"map","entries":[["selectable",true],["columns",[{"type":"map","entries":[["field","index"],["sorter","number ...

# %% [markdown]
# ## How does gender affect running times?

# %%
berlin_marathon.dtypes
# Out:
# year          int64
# country      object
# gender       object
# age         float64
# time         object
# time_hrs    float64
# dtype: object

# %%
age_data_pipeline = (
    idf
    .sort_values(by = 'year', ascending = False)
    .groupby(['age'])['time_hrs'].mean()
    .to_frame()
    .reset_index()
    .reset_index(drop=True)

)
age_data_plot = age_data_pipeline.hvplot(
    kind = 'scatter',
    title = 'Average time by age', 
    x = 'age',
    y = 'time_hrs')
age_data_plot
# Out:
# <div id='b37567c3-cd44-418f-a7ed-f14ab3f1157d'>
#   <div id="ea97b87d-7a50-4a38-862d-8859023834e0" data-root-id="b37567c3-cd44-418f-a7ed-f14ab3f1157d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"53ea8d47-9038-4d6a-9d2f-5695dbbf8164":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"b37567c3-cd44-418f-a7ed-f14ab3f1157d","attributes":{"name":"Row06609","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"a123442d-4808-4de4-8e90-c23980f49935","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"776f39d3-502b-4d50-9ef7-983cba736eea","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"46b201d9-727c-4de4-9ef6-0aff202f184b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"68981924-df04-4a6d-ad8e-45d8466b4614","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"8b062682-b5d2-43cc-a6f3-09f903a4d6e8","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"6305c1c0-1c90-4ddd-a970-0b6d727de821","attributes":{"tags":[[["age","age",null]],[]],"start":15.342857142857143,"end":82.65714285714286,"reset_start":15.342857142857143,"reset_end":82.65714285714286}},"y_range":{"type":"object","name":"Range1d","id":"1c5f184d-5ffd-4bf3-b7bb-38706fcbd7d1","attributes":{"tags":[[["time_hrs","time_hrs",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":3.7439616027430436,"end":6.075233369061576,"reset_start":3.7439616027430436,"reset_end":6.075233369061576}},"x_scale":{"type":"object","name":"LinearScale","id":"8068f726-bdbe-422a-afe0-1643133c85a3"},"y_scale":{"type":"object","name":"LinearScale","id":"9ece4e21-69c9-4653-a883-a0292623d67f"},"title":{"type":"object","name":"Title","id":"8dd99197-cc7f-4bc9-8890-038090b308ad","attributes":{"text":"Average time by age","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"a786e26f-c523-4f8c-aa88-a97735e029fd","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"12219abc-45b5-493f-ab35-61f64a2ea119","attributes":{"selected":{"type":"object","name":"Selection","id":"99a7dd73-43bb-4697-864d-aaa0714fe0cc","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"e4ff7bf0-b1b8-4a72-a265-5259edc41ef0"},"data":{"type":"map","entries":[["age",{"type":"ndarray","array":{"type":"bytes","data":"AAAAAAAAMkAAAAAAAAA0QAAAAAAAAD5AAAAAAACAQUAAAAAAAABEQAAAAAAAgEZAAAAAAAAASUAAAAAAAIBLQAAAAAAAAE5AAAAAAABAUEAAAAAAAIBRQAAAAAAAwFJAAAAAAAAAVEA="},"shape":[13],"dtype":"float64","order":"little"}],["time_hrs",{"type":"ndarray","array":{"type":"bytes","data":"JuSiFnk4EEDztRvu0pUPQNm0W/WAgQ9AxRUDZuuRD0As7Hy9APYPQOcfp/KoQRBAABMsb9e8EEA0gKm+VVYRQM0tHSPCBBJAfrzrtA7rEkBTJidNIRAUQJzqiHkNThVA0/BFkRqGF0A="},"shape":[13],"dtype":"float64","order":"little"}]]}}},"view":{"type":"object","name":"CDSView","id":"426b255a-7f1d-432a-a8af-a4dc5c4f6af7","attributes":{"filter":{"type":"object","name":"AllIndices","id":"a5b81534-d1cb-4b86-9ac9-0de4f88c55af"}}},"glyph":{"type":"object","name":"Scatter","id":"5104a160-c197-46f6-9d7c-5b7bf6547259","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"age"},"y":{"type":"field","field":"time_hrs"},"size":{"type":"value","value":5.477225575051661},"line_color":{"type":"value","value":"#30a2da"},"fill_color":{"type":"value","value":"#30a2da"},"hatch_color":{"type":"value","value":"#30a2da"}}},"selection_glyph":{"type":"object","name":"Scatter","id":"67920446-a477-4eda-9acb-48063d499c58","attributes":{"tags":["apply_ranges"],"x":{ ...

# %% [markdown]
# ## How does gender affect times?

# %%
gender_data = idf[(idf['gender'] != 'X') & (idf['gender'] != '–') ]
gender_data_pipeline = (
    gender_data
    .sort_values(by = 'year')
    .groupby(['gender', 'year'])['time_hrs'].mean()
    .to_frame()
    .reset_index()
    .reset_index(drop=True)

)
gender_data_plot = gender_data_pipeline.hvplot(
    kind = 'scatter',
    by = 'gender',
    title = 'Average time by gender', 
    x = 'year',
    y = 'time_hrs')
gender_data_plot
# Out:
# <div id='0c2f7455-165f-4f0b-bd7f-fb59bf8dc713'>
#   <div id="f1cdfb51-d409-4cbb-b305-5bfb4773df67" data-root-id="0c2f7455-165f-4f0b-bd7f-fb59bf8dc713" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b13bbc4b-2ce5-46a7-b731-b3f84b0c678d":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"0c2f7455-165f-4f0b-bd7f-fb59bf8dc713","attributes":{"name":"Row18898","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"53a5d225-646c-434f-9cdb-30ca0c8b74b0","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"203a0104-fec2-44d4-bd34-a927c175e04f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"c9370cb5-ac62-4301-b2ce-65e4fba1cb65","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"61a9ad91-3318-4078-bac1-9d1fbadd7b6b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"52c196e5-8f8a-4c54-8f91-399de3c4121c","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"c9580bc5-6528-456b-b488-f2160fd395b4","attributes":{"tags":[[["year","year",null]],[]],"start":1971.9,"end":2025.1,"reset_start":1971.9,"reset_end":2025.1}},"y_range":{"type":"object","name":"Range1d","id":"4f06c948-5a02-46d2-9d9b-333f569a74b6","attributes":{"tags":[[["time_hrs","time_hrs",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":3.2185775947085924,"end":4.7693237068827345,"reset_start":3.2185775947085924,"reset_end":4.7693237068827345}},"x_scale":{"type":"object","name":"LinearScale","id":"21f22bac-6ab2-4be6-b733-e05666fd1712"},"y_scale":{"type":"object","name":"LinearScale","id":"0f701e79-d425-4937-ae72-32a0fbc1549c"},"title":{"type":"object","name":"Title","id":"2d322195-9096-4863-9b44-4bfec5dbd694","attributes":{"text":"Average time by gender","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"9f09b4b3-83ab-4c61-a82a-96029d6dff85","attributes":{"name":"female","data_source":{"type":"object","name":"ColumnDataSource","id":"5170b701-5db7-42fe-b248-12dabc18ebd1","attributes":{"selected":{"type":"object","name":"Selection","id":"bbf4cee5-00fe-46ab-806c-5c63719b9e8d","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"f54ca7eb-a0b8-4992-af46-273c48d8818f"},"data":{"type":"map","entries":[["year",{"type":"ndarray","array":{"type":"bytes","data":"vQcAAL4HAAC/BwAAwAcAAMEHAADCBwAAwwcAAMQHAADFBwAAxgcAAMcHAADIBwAAyQcAAMsHAADMBwAAzQcAAM4HAADPBwAA0AcAANEHAADSBwAA0wcAANQHAADVBwAA1gcAANcHAADYBwAA2QcAANoHAADbBwAA3AcAAN0HAADeBwAA3wcAAOAHAADhBwAA4gcAAOUHAADmBwAA5wcAAA=="},"shape":[40],"dtype":"int32","order":"little"}],["time_hrs",{"type":"ndarray","array":{"type":"bytes","data":"..."},"shape":[40],"dtype":"float64","order":"little"}],["gender",["female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female"]]]}}},"view":{"type":"object","name":"CDSView","id":"d29b5ffd-6c98-41f3-8925-46fd5efcb409","attributes":{"filter":{"type":"object","name":"AllIndices","id":"4575f4e9-8027-4ce0-a8e2-a67cba8f6fb4"}}},"glyph":{"type":"object","name":"Scatter","id":"4cda35dd-595e-48ef-9134-06e018a11bdf","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"year"},"y":{"type":"field","field":"time_hrs"},"size":{"type":"value","value":5.47722557505166 ...

# %% [markdown]
# ### What are the average time differences

# %%
time_diff = idf[(idf['gender'] != 'X') & (idf['gender'] != '–') ]
time_diff = time_diff.groupby('gender')['time_hrs'].mean().reset_index()
time_diff[time_diff['gender']=='male']['time_hrs'] - time_diff[time_diff['gender']=='male']['time_hrs']
# Out:
# <div id='6e963f68-a8ae-44d8-a78b-d777e3a08008'>
#   <div id="a6813c26-d139-4228-9ea0-15c72f0993d9" data-root-id="6e963f68-a8ae-44d8-a78b-d777e3a08008" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a9fab803-e218-4df1-9f94-1e878c1d94b5":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"6e963f68-a8ae-44d8-a78b-d777e3a08008","attributes":{"name":"Row25311","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"ddac4c23-c08b-4204-aee5-ea45dbfc51ba","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"353d4543-bd41-48ed-86c8-91594fbf2875","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a3393357-1beb-4469-b761-adbdc5ba0696","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"64e704c1-de80-46d0-924d-2e98cb5abdf6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"3f033f82-aa09-41b5-81f3-055f009b5384","attributes":{"name":"Column25296","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ddac4c23-c08b-4204-aee5-ea45dbfc51ba"},{"id":"353d4543-bd41-48ed-86c8-91594fbf2875"},{"id":"a3393357-1beb-4469-b761-adbdc5ba0696"},{"id":"64e704c1-de80-46d0-924d-2e98cb5abdf6"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"ad2bb54f-4520-4b17-8e43-8eb35ce11ba5","attributes":{"name":"Column25308","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ddac4c23-c08b-4204-aee5-ea45dbfc51ba"},{"id":"353d4543-bd41-48ed-86c8-91594fbf2875"},{"id":"a3393357-1beb-4469-b761-adbdc5ba0696"},{"id":"64e704c1-de80-46d0-924d-2e98cb5abdf6"}],"margin":0,"align":"start"}},{"type":"object","name":"Row","id":"5948fbae-ef23-4402-a07b-b5a7fbecc386","attributes":{"name":"Row25305","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ddac4c23-c08b-4204-aee5-ea45dbfc51ba"},{"id":"353d4543-bd41-48ed-86c8-91594fbf2875"},{"id":"a3393357-1beb-4469-b761-adbdc5ba0696"},{"id":"64e704c1-de80-46d0-924d-2e98cb5abdf6"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"f6ee7ece-1004-40f9-8984-a883d7599422","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ddac4c23-c08b-4204-aee5-ea45dbfc51ba"},{"type":"object","name":"ImportedStyleSheet","id":"d51e523d-9c4c-4e5b-b3d4-7e2b949905df","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/dataframe.css"}},{"id":"a3393357-1beb-4469-b761-adbdc5ba0696"},{"id":"64e704c1-de80-46d0-924d-2e98cb5abdf6"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;time_hrs&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n    &lt;/tr&gt;\n  &lt;/tbody&gt;\n&lt;/table&gt;","disable_math":true}}]}}]}}]}},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d3dff145-ce8e-4eae-9cf5-0f1b6ca83624","attributes":{"plot_id":"6e963f68-a8ae-44d8-a78b-d777e3a08008","comm_id":" ...
#   var render_items = [{"docid":"a9fab803-e218-4df1-9f94-1e878c1d94b5","roots":{"6e963f68-a8ae-44d8-a78b-d777e3a08008":"a6813c26-d139-4228-9ea0-15c72f0993d9"},"root_ids":["6e963f68-a8ae-44d8-a78b-d777e3a08008"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }

# %% [markdown]
# ## Where are most runners from?
# - Where do most runners come from?
#     - Germany
# - Where are the shortest times from?
#     - Kenya, followed by Ethiopia. Even tho Germany had the most participants ahaha
# - Are these two places the same?
#     - no. no they are not.

# %%
runners_count = berlin_marathon.groupby(['country', 'gender']).size().sort_values(ascending = False)
runners_count = runners_count[runners_count > 1000]
runners_count_plot = runners_count.hvplot(kind = 'bar', 
                                               stacked = True, 
                                               rot = 45,
                                               title = 'Where are most runners from?')
runners_count_plot
# Out:
# :Bars   [country,gender]   (0)

# %% [markdown]
# ## Where are the top 50 runners from?

# %%
gender_selector = pn.widgets.Select(options=['All', 'male', 'female'], value='Men', name='Select Gender')
gender_selector
# Out:
# Select(options=['All', 'male', 'female'], value='All')

# %%
gender_selector = pn.widgets.Select(options=['male', 'female'], value='Men', name='Select Gender')
top_50_pipeline = (
    idf[
        (idf['gender'] == gender_selector)
    ]
    .dropna(subset=['country', 'gender']).sort_values(by = 'time_hrs')[:50]
    .groupby(['country', 'gender']).size()
    .sort_values(ascending = False)
    .to_frame()
    .reset_index()
    .reset_index(drop=True)
)
top_50_plot = top_50_pipeline.hvplot(kind = 'bar', 
                       x = 'country',
                       ylabel = 'count',
                       stacked = True, 
                       rot = 45,
                       title = 'Where are the top 50 runners from?')

# %% [raw]
# berlin_marathon = berlin_marathon.dropna(subset=['country', 'gender']).sort_values(by = 'time_hrs')
# berlin_marathon_ = berlin_marathon[:50].groupby(['country', 'gender']).size().sort_values(ascending = False)#.unstack(fill_value = 0)
# berlin_marathon_plot = berlin_marathon_.hvplot(kind = 'bar',
#                                                stacked = True,
#                                                rot = 45,
#                                                title = 'Where are the top 50 runners from?')
# berlin_marathon_plot

# %%
plot_selector = pn.widgets.Select(options=['Top 50', 'Runner Population'], name='Select Plot')
@pn.depends(plot_selector.param.value)
def reactive_plot(selected_plot):
    if selected_plot == 'Top 50':
        return top_50_plot
    elif selected_plot == 'Runner Population':
        return runners_count_plot

# %%
template = pn.template.FastListTemplate(
    title = 'Berlin Marathon runners',
    sidebar = [pn.pane.Markdown("# Berlin Marathon!"),
               [pn.pane.Markdown("#### ")],
               year_slider
              ],
    main = [pn.Row(pn.Column(overall_times_plot), pn.Column(marathon_table)),#, top_50_plot)),
           pn.Row(pn.Column(age_data_plot), pn.Column(plot_selector, reactive_plot))]
)
template.servable()
# Out:
# FastListTemplate
#     [js_area] HTML(None, height=0, margin=0, sizing_mode='fixed', width=0)
#     [actions] TemplateActions()
#     [browser_info] BrowserInfo(dark_mode=True, device_pixel_ratio=1.7999999523162842, language='en-CA', timezone='America/Toronto', timezone_offset=300, webdriver=False)
#     [busy_indicator] LoadingSpinner(height=20, width=20)
#     [6285531472] Row
#         [0] Column
#             [0] HoloViews(NdOverlay, height=300, sizing_mode='fixed', width=700)
#         [1] Column
#             [0] Interactive(Interactive)
#     [6285843344] Row
#         [0] Column
#             [0] Interactive(Interactive)
#         [1] Column
#             [0] Select(options=['Top 50', 'Runner P...], value='Top 50')
#             [1] ParamFunction(function, _pane=Interactive, defer_load=False)
#     [6259280400] Markdown(str)
#     [6286011856] Str(list)
#     [5184735056] IntSlider(end=2023, name='Year slider', start=1974, value=2023)

# %% [raw]
# reactive_plot
